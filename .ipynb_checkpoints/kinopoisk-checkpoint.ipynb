# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

url = "https://www.kinopoisk.ru/lists/movies/popular-series/"

# Запуск браузера
driver = webdriver.Chrome()
driver.get(url)

# Получение HTML-кода после выполнения JavaScript
html = driver.page_source

# Создание объекта BeautifulSoup для парсинга HTML
soup = BeautifulSoup(html, 'html.parser')

# Находим все элементы с классом "styles_root__ti07r"
movie_divs = soup.find_all('div', class_='styles_root__ti07r')

# Списки для хранения данных
data = []

# Итерируемся по каждому блоку и извлекаем необходимые данные
for i, div in enumerate(movie_divs, start=1):
    # Название фильма
    title = div.find('span', class_='styles_activeMovieTittle__kJdJj').text.strip()

    # Год и продолжительность
    secondary_title = div.find('span', class_='desktop-list-main-info_secondaryText__M_aus').text.strip()

    # Описание фильма
    description = div.find_all('span', class_='desktop-list-main-info_truncatedText__IMQRP')[0].text.strip()

    # Актеры
    actors_element = div.find_all('span', class_='desktop-list-main-info_truncatedText__IMQRP')
    actors = actors_element[1].text.strip() if len(actors_element) > 1 else "Actors not found"

    # Рейтинг Кинопоиска
    rating_element = div.find('span', class_='styles_kinopoiskValuePositive__vOb2E')
    rating = rating_element.text.strip() if rating_element else "Rating not found"

    # Добавляем данные в список
    data.append([i, title, secondary_title, description, actors, rating])

# Создаем DataFrame
header = ['№', 'Title', 'Year and average duration', 'Description', 'Actors', 'Kinopoisk rating']
df = pd.DataFrame(data, columns=header)

# Выводим DataFrame
print(df)

# Сохраняем DataFrame в CSV файл
df.to_csv('final-project.csv', sep=';', encoding='utf-8', index=False)

# Закрытие браузера
driver.quit()
# Out:
#      №                                  Title Year and average duration  \
# 0    1        Слово пацана. Кровь на асфальте         2023–..., 50 мин.
# 1    2                                 Цикады             2023, 50 мин.
# 2    3                           Кибердеревня             2023, 25 мин.
# 3    4                      Волшебный участок             2023, 50 мин.
# 4    5                        Жизнь по вызову         2022–..., 34 мин.
# 5    6                                  Фишер             2023, 60 мин.
# 6    7                               Пищеблок         2021–..., 50 мин.
# 7    8                                  Кухня        2012–2016, 25 мин.
# 8    9                          Атака титанов      , 2013–2023, 24 мин.
# 9   10  Мой маленький пони: Дружба — это чудо      , 2010–2019, 22 мин.
# 10  11                           Чёрная весна             2022, 50 мин.
# 11  12                      Трудные подростки         2019–..., 25 мин.
# 12  13                           Отмороженные             2023, 24 мин.
# 13  14                                Триггер         2018–..., 52 мин.
# 14  15                      Мама будет против             2023, 24 мин.
# 15  16                         Сама виновата?             2023, 30 мин.
# 16  17                                Оффлайн         2022–..., 52 мин.
# 17  18                               Эпидемия         2018–..., 48 мин.
# 18  19                    Кеша должен умереть                      2023
# 19  20                           Объяснялкины                  2023–...
# 20  21                                 Смычок             2022, 45 мин.
# 21  22                            Рик и Морти       , 2013–..., 23 мин.
# 22  23                        Банда «ЗИГ ЗАГ»             2023, 48 мин.
# 23  24                                Госпожа                  2023–...
# 24  25                         Игра престолов      , 2011–2019, 55 мин.
# 25  26                                 Пацаны       , 2019–..., 60 мин.
# 26  27                   Мир! Дружба! Жвачка!         2020–..., 45 мин.
# 27  28                              Контейнер        2021–2023, 48 мин.
# 28  29                   Голубоглазый самурай           , 2023, 45 мин.
# 29  30                          Во все тяжкие      , 2008–2013, 47 мин.
# 30  31                            Против всех         2022–..., 24 мин.
# 31  32                     Сверхъестественное      , 2005–2020, 43 мин.
# 32  33                              Два холма         2022–..., 26 мин.
# 33  34                      Совершенно другой                , 2023–...
# 34  35              Благословение небожителей       , 2020–..., 35 мин.
# 35  36                        Детство Шелдона       , 2017–..., 30 мин.
# 36  37                                Бригада             2002, 52 мин.
# 37  38                    Царство падальщиков           , 2023, 24 мин.
# 38  39                                   Топи             2021, 55 мин.
# 39  40                              Зимородок      , 2022–..., 120 мин.
# 40  41                                Новичок       , 2018–..., 43 мин.
# 41  42                                  Голяк       , 2019–..., 43 мин.
# 42  43                                 Букины             2023, 24 мин.
# 43  44                       Секс. До и после         2023–..., 15 мин.
# 44  45                              Бесстыжие      , 2011–2021, 55 мин.
# 45  46                           Библиотекарь             2023, 50 мин.
# 46  47                             Убить Риту             2023, 50 мин.
# 47  48                     Короче, план такой                  2023–...
# 48  49                               Полярный         2019–..., 25 мин.
# 49  50                Бизон: Дело манекенщицы         2023–..., 52 мин.
#
#                                           Description  \
# 0          Россия • драма  Режиссёр: Жора Крыжовников
# 1           Россия • драма  Режиссёр: Евгений Стычкин
# 2      Россия • фантастика  Режиссёр: Сергей Васильев
# 3           Россия • боевик  Режиссёр: Степан Гордеев
# 4           Россия • драма  Режиссёр: Сарик Андреасян
# 5        Россия • детектив  Режиссёр: Сергей Тарамаев
# 6   Россия • триллер  Режиссёр: Святослав Подгаевский
# 7        Россия • комедия  Режиссёр: Дмитрий Дьяченко
# 8              Япония • аниме  Режиссёр: Тэцуро Араки
# 9             США • мультфильм  Режиссёр: Джим Миллер
# 10          Россия • драма  Режиссёр: Сергей Тарамаев
# 11           Россия • драма  Режиссёр: Рустам Ильясов
# 12           Россия • комедия  Режиссёр: Аня Мирохина
# 13            Россия • драма  Режиссёр: Дмитрий Тюрин
# 14        Россия • комедия  Режиссёр: Артур Румынский
# 15          Россия • драма  Режиссёр: Сарик Андреасян
# 16         Россия • триллер  Режиссёр: Кирилл Плетнёв
# 17         Россия • драма  Режиссёр: Павел Костомаров
# 18     Россия • драма  Режиссёр: Константин Богомолов
# 19   Россия • мультфильм  Режиссёр: Евгений Блинников
# 20            Россия • драма  Режиссёр: Александр Цой
# 21            США • мультфильм  Режиссёр: Уэсли Арчер
# 22      Россия • детектив  Режиссёр: Виталий Воробьев
# 23           Россия • драма  Режиссёр: Юлия Трофимова
# 24              США • фэнтези  Режиссёр: Дэвид Наттер
# 25         США • фантастика  Режиссёр: Филип Сгриккиа
# 26             Россия • драма  Режиссёр: Илья Аксенов
# 27         Россия • драма  Режиссёр: Максим Свешников
# 28         США • мультфильм  Режиссёр: Эрл А. Хибберт
# 29          США • криминал  Режиссёр: Мишель МакЛарен
# 30        Россия • комедия  Режиссёр: Михаил Соловьев
# 31             США • фэнтези  Режиссёр: Роберт Сингер
# 32       Россия • комедия  Режиссёр: Дмитрий Грибанов
# 33      Турция • детектив  Режиссёр: Неслихан Ешилюрт
# 34            Китай • мультфильм  Режиссёр: Ли Хаолин
# 35                США • комедия  Режиссёр: Алекс Рейд
# 36          Россия • драма  Режиссёр: Алексей Сидоров
# 37             США • мультфильм  Режиссёр: Бенжи Брук
# 38       Россия • триллер  Режиссёр: Владимир Мирзоев
# 39          Турция • драма  Режиссёр: Бурджу Алптекин
# 40                   США • боевик  Режиссёр: Билл Роу
# 41  Великобритания • комедия  Режиссёр: Ричард Сто...
# 42         Россия • комедия  Режиссёр: Гарик Петросян
# 43              Россия • драма  Режиссёр: Дарья Мороз
# 44           США • драма  Режиссёр: Иэн Б. МакДональд
# 45     Россия • фэнтези  Режиссёр: Игорь Твердохлебов
# 46       Россия • криминал  Режиссёр: Мария Агранович
# 47           Россия • комедия  Режиссёр: Марк Горобец
# 48         Россия • комедия  Режиссёр: Михаил Старчак
# 49        Россия • детектив  Режиссёр: Сергей Чекалов
#
#                                                Actors  Kinopoisk rating
# 0            В ролях: Иван Янковский, Рузиль Минекаев               9.0
# 1             В ролях: Григорий Верник, Софья Аржаных               7.6
# 2          В ролях: Сергей Чихачёв, Григорий Скряпкин               8.2
# 3               В ролях: Николай Наумов, Ева Смирнова               8.1
# 4            В ролях: Павел Прилучный, Наталья Рудова  Rating not found
# 5          В ролях: Иван Янковский, Александра Бортич               7.8
# 6              В ролях: Пётр Натаров, Даниил Вершинин               7.4
# 7            В ролях: Дмитрий Назаров, Марк Богатырев               8.2
# 8                      В ролях: Юки Кадзи, Юи Исикава               8.7
# 9                     В ролях: Эшли Болл, Тара Стронг               8.1
# 10               В ролях: Глеб Калюжный, Артем Кошман               7.8
# 11            В ролях: Никита Волков, Виталий Андреев               8.1
# 12                  В ролях: Ян Цапник, Влад Коноплёв               8.0
# 13        В ролях: Максим Матвеев, Игорь Костолевский               8.5
# 14            В ролях: Сергей Ершов, Роман Постовалов               7.9
# 15           В ролях: Анна Глаубэ, Игорь Царегородцев               7.4
# 16              В ролях: Никита Ефремов, Денис Шведов               7.8
# 17             В ролях: Виктория Исакова, Кирилл Кяро               7.6
# 18  В ролях: Константин Богомолов, Александра Ребенок  Rating not found
# 19         В ролях: Дмитрий Сыендук, Виктория Зайцева               8.2
# 20         В ролях: Марк Эйдельштейн, Катерина Беккер               7.3
# 21             В ролях: Джастин Ройланд, Крис Парнелл               9.0
# 22         В ролях: Игорь Петренко, Александр Устюгов               7.5
# 23           В ролях: Никита Ефремов, Евгения Громова  Rating not found
# 24                В ролях: Питер Динклэйдж, Лина Хиди               9.0
# 25                    В ролях: Карл Урбан, Джек Куэйд               8.3
# 26                В ролях: Егор Губарев, Егор Абрамов               7.9
# 27        В ролях: Оксана Акиньшина, Филипп Янковский               7.8
# 28                 В ролях: Майя Эрскин, Джордж Такэй               8.5
# 29                В ролях: Брайан Крэнстон, Анна Ганн               8.9
# 30      В ролях: Николай Добрынин, Александра Урсуляк  Rating not found
# 31             В ролях: Джаред Падалеки, Дженсен Эклс               8.2
# 32      В ролях: Пелагея Невзорова, Никита Кологривый               7.6
# 33                  В ролях: Ханде Эрчел, Бурак Дениз               8.1
# 34                  В ролях: Цзян Гуантао, Ма Чжэнъян               8.6
# 35                   В ролях: Иэн Армитедж, Зои Перри               8.4
# 36            В ролях: Сергей Безруков, Дмитрий Дюжев               8.3
# 37                 В ролях: Сунита Мани, Вунми Мосаку               8.5
# 38          В ролях: Иван Янковский, Тихон Жизневский  Rating not found
# 39        В ролях: Афра Сарачоглу, Мерт Рамазан Демир               8.0
# 40               В ролях: Нэйтан Филлион, Алисса Диас               8.3
# 41               В ролях: Мишель Кигэн, Джозеф Гилган               8.6
# 42         В ролях: Виктор Логинов, Наталья Бочкарёва  Rating not found
# 43      В ролях: Ангелина Пахомова, Игорь Миркурбанов               7.3
# 44            В ролях: Уильям Х. Мэйси, Итан Каткоски               8.7
# 45         В ролях: Никита Ефремов, Евгения Дмитриева               7.5
# 46             В ролях: Евгения Борзых, Артём Быстров               7.5
# 47            В ролях: Кирилл Нагиев, София Каштанова               7.4
# 48        В ролях: Михаил Пореченков, Иван Охлобыстин  Rating not found
# 49              В ролях: Сергей Безруков, Айсель Прат               8.1
